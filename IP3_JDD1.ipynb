# %% [markdown]
# ## Individual Project 3
# Joshua Dow
#
# DS160-01
#
# Spring 22

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Part 1
# **1**
# You have been given four .csv files. Each file represents a different German power company’s wind turbine
# power generation data. Your first goal is to merge these datasets together. To do this, write a function that
# takes a filename (of and returns a dataframe.

# %%
am=pd.read_csv('Amprion.csv')
he=pd.read_csv('50Hertz.csv')
te=pd.read_csv('TenneTTSO.csv')
tr=pd.read_csv('TransnetBW.csv')

# %%
am
# Out:
#            Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  01:15:00  \
# 0    23/08/2019         5         5         6         7         6         5
# 1    24/08/2019        62        60        55        55        54        52
# 2    25/08/2019        29        29        29        30        28        27
# 3    26/08/2019        13        12        12        11        12        12
# 4    27/08/2019        21        20        19        16        15        14
# ..          ...       ...       ...       ...       ...       ...       ...
# 392  18/09/2020       116       117       117       113       114       114
# 393  19/09/2020        91        92        91        92        92        90
# 394  20/09/2020        60        59        58        55        52        50
# 395  21/09/2020        44        44        40        39        37        36
# 396  22/09/2020        11        11        10        10        10        10
#
# ...

# %%
he
# Out:
#            Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  01:15:00  \
# 0    23/08/2019        74        73        63        55        54        53
# 1    24/08/2019        37        38        35        35        31        32
# 2    25/08/2019        93        88        85        81        76        80
# 3    26/08/2019        72        66        59        54        48        46
# 4    27/08/2019        39        38        36        36        34        31
# ..          ...       ...       ...       ...       ...       ...       ...
# 392  18/09/2020        73        72        66        62        59        58
# 393  19/09/2020        64        64        64        68        66        66
# 394  20/09/2020       111       102        95        87        82        83
# 395  21/09/2020        57        53        47        44        43        42
# 396  22/09/2020        51        48        44        42        40        39
#
# ...

# %%
te
# Out:
#            Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  01:15:00  \
# 0    23/08/2019      9.68     10.16     10.94     11.39     12.09     12.79
# 1    24/08/2019     67.94     67.52     64.48     64.78     65.75     65.07
# 2    25/08/2019     89.38     88.95     85.13     82.74     81.46     77.92
# 3    26/08/2019     33.71     31.84     32.75     33.33     32.02     30.97
# 4    27/08/2019     52.65     47.95     44.61     43.80     41.00     41.23
# ..          ...       ...       ...       ...       ...       ...       ...
# 392  18/09/2020    124.69    121.15    116.35    117.81    113.87    112.95
# 393  19/09/2020    136.90    134.27    127.98    121.21    116.74    112.38
# 394  20/09/2020     82.05     79.81     80.18     80.94     79.70     77.91
# 395  21/09/2020     55.75     53.17     51.77     50.08     48.95     47.45
# 396  22/09/2020     11.66     11.72     11.08      9.94     10.08      9.36
#
# ...

# %%
tr
# Out:
#            Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  01:15:00  \
# 0    23/08/2019      1.44      1.38      1.38      1.50      1.77      1.87
# 1    24/08/2019     22.43     22.25     22.03     23.34     24.81     22.90
# 2    25/08/2019      0.75      1.06      0.72      1.00      0.80      0.95
# 3    26/08/2019      0.56      0.85      0.56      0.40      0.46      0.39
# 4    27/08/2019      1.08      1.02      0.98      0.84      0.57      0.46
# ..          ...       ...       ...       ...       ...       ...       ...
# 392  18/09/2020     43.00     44.43     44.33     46.67     46.67     46.67
# 393  19/09/2020     37.43     35.22     36.60     33.44     32.67     36.00
# 394  20/09/2020      5.00      5.00      5.00      5.00      4.22      4.22
# 395  21/09/2020      3.44      3.44      3.44      3.44      2.67      3.44
# 396  22/09/2020      1.33      2.00      2.00      2.00      1.00      1.00
#
# ...

# %% [markdown]
# **1.a**
# Convert the Date column to a date (notice, the data are in d/m/y format – take that into consider
# when you convert.

# %%
am['Date'] = pd.to_datetime(am['Date'])
he['Date'] = pd.to_datetime(he['Date'])
te['Date'] = pd.to_datetime(te['Date'])
tr['Date'] = pd.to_datetime(tr['Date'])

# %%
am
# Out:
#           Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  01:15:00  \
# 0   2019-08-23         5         5         6         7         6         5
# 1   2019-08-24        62        60        55        55        54        52
# 2   2019-08-25        29        29        29        30        28        27
# 3   2019-08-26        13        12        12        11        12        12
# 4   2019-08-27        21        20        19        16        15        14
# ..         ...       ...       ...       ...       ...       ...       ...
# 392 2020-09-18       116       117       117       113       114       114
# 393 2020-09-19        91        92        91        92        92        90
# 394 2020-09-20        60        59        58        55        52        50
# 395 2020-09-21        44        44        40        39        37        36
# 396 2020-09-22        11        11        10        10        10        10
#
# ...

# %%
he
# Out:
#           Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  01:15:00  \
# 0   2019-08-23        74        73        63        55        54        53
# 1   2019-08-24        37        38        35        35        31        32
# 2   2019-08-25        93        88        85        81        76        80
# 3   2019-08-26        72        66        59        54        48        46
# 4   2019-08-27        39        38        36        36        34        31
# ..         ...       ...       ...       ...       ...       ...       ...
# 392 2020-09-18        73        72        66        62        59        58
# 393 2020-09-19        64        64        64        68        66        66
# 394 2020-09-20       111       102        95        87        82        83
# 395 2020-09-21        57        53        47        44        43        42
# 396 2020-09-22        51        48        44        42        40        39
#
# ...

# %%
te
# Out:
#           Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  01:15:00  \
# 0   2019-08-23      9.68     10.16     10.94     11.39     12.09     12.79
# 1   2019-08-24     67.94     67.52     64.48     64.78     65.75     65.07
# 2   2019-08-25     89.38     88.95     85.13     82.74     81.46     77.92
# 3   2019-08-26     33.71     31.84     32.75     33.33     32.02     30.97
# 4   2019-08-27     52.65     47.95     44.61     43.80     41.00     41.23
# ..         ...       ...       ...       ...       ...       ...       ...
# 392 2020-09-18    124.69    121.15    116.35    117.81    113.87    112.95
# 393 2020-09-19    136.90    134.27    127.98    121.21    116.74    112.38
# 394 2020-09-20     82.05     79.81     80.18     80.94     79.70     77.91
# 395 2020-09-21     55.75     53.17     51.77     50.08     48.95     47.45
# 396 2020-09-22     11.66     11.72     11.08      9.94     10.08      9.36
#
# ...

# %%
tr
# Out:
#           Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  01:15:00  \
# 0   2019-08-23      1.44      1.38      1.38      1.50      1.77      1.87
# 1   2019-08-24     22.43     22.25     22.03     23.34     24.81     22.90
# 2   2019-08-25      0.75      1.06      0.72      1.00      0.80      0.95
# 3   2019-08-26      0.56      0.85      0.56      0.40      0.46      0.39
# 4   2019-08-27      1.08      1.02      0.98      0.84      0.57      0.46
# ..         ...       ...       ...       ...       ...       ...       ...
# 392 2020-09-18     43.00     44.43     44.33     46.67     46.67     46.67
# 393 2020-09-19     37.43     35.22     36.60     33.44     32.67     36.00
# 394 2020-09-20      5.00      5.00      5.00      5.00      4.22      4.22
# 395 2020-09-21      3.44      3.44      3.44      3.44      2.67      3.44
# 396 2020-09-22      1.33      2.00      2.00      2.00      1.00      1.00
#
# ...

# %% [markdown]
# **1.b**
# Since none of the files have a column for company, you need to add one called Company that
# contains the Company name (you can extract this from .csv filename. Hint: dataframes have an
# insert function.

# %%
am.insert(0, "Company", ['Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion','Amprion',])

# %%
am
# Out:
#      Company       Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  \
# 0    Amprion 2019-08-23         5         5         6         7         6
# 1    Amprion 2019-08-24        62        60        55        55        54
# 2    Amprion 2019-08-25        29        29        29        30        28
# 3    Amprion 2019-08-26        13        12        12        11        12
# 4    Amprion 2019-08-27        21        20        19        16        15
# ..       ...        ...       ...       ...       ...       ...       ...
# 392  Amprion 2020-09-18       116       117       117       113       114
# 393  Amprion 2020-09-19        91        92        91        92        92
# 394  Amprion 2020-09-20        60        59        58        55        52
# 395  Amprion 2020-09-21        44        44        40        39        37
# 396  Amprion 2020-09-22        11        11        10        10        10
#
#      01:15:00  01:30:00  01:45:00  ...  21:30:00  21:45:00  22:00:00  \
# ...

# %% [markdown]
# **2**
# Execute your function four times, passing each file to it. Once complete, you will have four dataframes that
# you can merge.

# %%
he.insert(0, "Company", ['50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz','50Hertz'])

# %%
te.insert(0, "Company", ['TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO','TenneTTSO',])

# %%
tr.insert(0, "Company", ['TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW','TransnetBW'])

# %%
he
# Out:
#      Company       Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  \
# 0    50Hertz 2019-08-23        74        73        63        55        54
# 1    50Hertz 2019-08-24        37        38        35        35        31
# 2    50Hertz 2019-08-25        93        88        85        81        76
# 3    50Hertz 2019-08-26        72        66        59        54        48
# 4    50Hertz 2019-08-27        39        38        36        36        34
# ..       ...        ...       ...       ...       ...       ...       ...
# 392  50Hertz 2020-09-18        73        72        66        62        59
# 393  50Hertz 2020-09-19        64        64        64        68        66
# 394  50Hertz 2020-09-20       111       102        95        87        82
# 395  50Hertz 2020-09-21        57        53        47        44        43
# 396  50Hertz 2020-09-22        51        48        44        42        40
#
#      01:15:00  01:30:00  01:45:00  ...  21:30:00  21:45:00  22:00:00  \
# ...

# %%
te
# Out:
#        Company       Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  \
# 0    TenneTTSO 2019-08-23      9.68     10.16     10.94     11.39     12.09
# 1    TenneTTSO 2019-08-24     67.94     67.52     64.48     64.78     65.75
# 2    TenneTTSO 2019-08-25     89.38     88.95     85.13     82.74     81.46
# 3    TenneTTSO 2019-08-26     33.71     31.84     32.75     33.33     32.02
# 4    TenneTTSO 2019-08-27     52.65     47.95     44.61     43.80     41.00
# ..         ...        ...       ...       ...       ...       ...       ...
# 392  TenneTTSO 2020-09-18    124.69    121.15    116.35    117.81    113.87
# 393  TenneTTSO 2020-09-19    136.90    134.27    127.98    121.21    116.74
# 394  TenneTTSO 2020-09-20     82.05     79.81     80.18     80.94     79.70
# 395  TenneTTSO 2020-09-21     55.75     53.17     51.77     50.08     48.95
# 396  TenneTTSO 2020-09-22     11.66     11.72     11.08      9.94     10.08
#
# ...

# %%
tr
# Out:
#         Company       Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  \
# 0    TransnetBW 2019-08-23      1.44      1.38      1.38      1.50      1.77
# 1    TransnetBW 2019-08-24     22.43     22.25     22.03     23.34     24.81
# 2    TransnetBW 2019-08-25      0.75      1.06      0.72      1.00      0.80
# 3    TransnetBW 2019-08-26      0.56      0.85      0.56      0.40      0.46
# 4    TransnetBW 2019-08-27      1.08      1.02      0.98      0.84      0.57
# ..          ...        ...       ...       ...       ...       ...       ...
# 392  TransnetBW 2020-09-18     43.00     44.43     44.33     46.67     46.67
# 393  TransnetBW 2020-09-19     37.43     35.22     36.60     33.44     32.67
# 394  TransnetBW 2020-09-20      5.00      5.00      5.00      5.00      4.22
# 395  TransnetBW 2020-09-21      3.44      3.44      3.44      3.44      2.67
# 396  TransnetBW 2020-09-22      1.33      2.00      2.00      2.00      1.00
#
# ...

# %% [markdown]
# **3**
# Stack the dataframes on top of each to produce one large dataframe that has 98 columns, one for company,
# one for date and one for each timepoint.

# %%
df=pd.concat([am,he,te,tr], ignore_index=True)

# %%
df
# Out:
#          Company       Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  \
# 0        Amprion 2019-08-23      5.00      5.00      6.00      7.00      6.00
# 1        Amprion 2019-08-24     62.00     60.00     55.00     55.00     54.00
# 2        Amprion 2019-08-25     29.00     29.00     29.00     30.00     28.00
# 3        Amprion 2019-08-26     13.00     12.00     12.00     11.00     12.00
# 4        Amprion 2019-08-27     21.00     20.00     19.00     16.00     15.00
# ...          ...        ...       ...       ...       ...       ...       ...
# 1583  TransnetBW 2020-09-18     43.00     44.43     44.33     46.67     46.67
# 1584  TransnetBW 2020-09-19     37.43     35.22     36.60     33.44     32.67
# 1585  TransnetBW 2020-09-20      5.00      5.00      5.00      5.00      4.22
# 1586  TransnetBW 2020-09-21      3.44      3.44      3.44      3.44      2.67
# 1587  TransnetBW 2020-09-22      1.33      2.00      2.00      2.00      1.00
#
# ...

# %%
df.sample(10)
# Out:
#          Company       Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  \
# 1572  TransnetBW 2020-07-09      8.67      8.89      8.89      7.33      6.56
# 882    TenneTTSO 2019-11-19    353.31    356.47    364.02    363.15    365.33
# 60       Amprion 2019-10-22     63.00     65.00     61.00     61.00     65.00
# 151      Amprion 2020-01-21     46.00     47.00     47.00     47.00     51.00
# 1523  TransnetBW 2020-07-20      2.00      2.00      2.00      2.78      2.78
# 465      50Hertz 2019-10-30     20.00     18.00     18.00     16.00     15.00
# 1316  TransnetBW 2019-12-26      9.44      6.89      5.09      4.20      3.75
# 1542  TransnetBW 2020-08-08      6.00      4.25      4.29      3.33      3.40
# 1056   TenneTTSO 2020-11-05    213.45    215.49    212.66    208.58    194.60
# 1587  TransnetBW 2020-09-22      1.33      2.00      2.00      2.00      1.00
#
#       01:15:00  01:30:00  01:45:00  ...  21:30:00  21:45:00  22:00:00  \
# ...

# %% [markdown]
# **4**
# You are going to visualize aggregate data first. To start, you need to create a new dataframe that is grouped
# by Company and the year (e.g. 50Hertz 2019, 50Hertz 2020, etc.). You can group by multiple columns by
# putting the column list in []. Group by the mean() function. The first few columns of your new dataframe
# should look like this:

# %%
df.columns
# Out:
# Index(['Company', 'Date', '00:00:00', '00:15:00', '00:30:00', '00:45:00',
#        '01:00:00', '01:15:00', '01:30:00', '01:45:00', '02:00:00', '02:15:00',
#        '02:30:00', '02:45:00', '03:00:00', '03:15:00', '03:30:00', '03:45:00',
#        '04:00:00', '04:15:00', '04:30:00', '04:45:00', '05:00:00', '05:15:00',
#        '05:30:00', '05:45:00', '06:00:00', '06:15:00', '06:30:00', '06:45:00',
#        '07:00:00', '07:15:00', '07:30:00', '07:45:00', '08:00:00', '08:15:00',
#        '08:30:00', '08:45:00', '09:00:00', '09:15:00', '09:30:00', '09:45:00',
#        '10:00:00', '10:15:00', '10:30:00', '10:45:00', '11:00:00', '11:15:00',
#        '11:30:00', '11:45:00', '12:00:00', '12:15:00', '12:30:00', '12:45:00',
#        '13:00:00', '13:15:00', '13:30:00', '13:45:00', '14:00:00', '14:15:00',
#        '14:30:00', '14:45:00', '15:00:00', '15:15:00', '15:30:00', '15:45:00',
#        '16:00:00', '16:15:00', '16:30:00', '16:45:00', '17:00:00', '17:15:00',
# ...

# %%
df1=df[['Company','Date','00:00:00', '00:15:00', '00:30:00', '00:45:00', '01:00:00', '01:15:00', '01:30:00', '01:45:00', '02:00:00', '02:15:00',
       '02:30:00', '02:45:00', '03:00:00', '03:15:00', '03:30:00', '03:45:00',
       '04:00:00', '04:15:00', '04:30:00', '04:45:00', '05:00:00', '05:15:00',
       '05:30:00', '05:45:00', '06:00:00', '06:15:00', '06:30:00', '06:45:00',
       '07:00:00', '07:15:00', '07:30:00', '07:45:00', '08:00:00', '08:15:00',
       '08:30:00', '08:45:00', '09:00:00', '09:15:00', '09:30:00', '09:45:00',
       '10:00:00', '10:15:00', '10:30:00', '10:45:00', '11:00:00', '11:15:00',
       '11:30:00', '11:45:00', '12:00:00', '12:15:00', '12:30:00', '12:45:00',
       '13:00:00', '13:15:00', '13:30:00', '13:45:00', '14:00:00', '14:15:00',
       '14:30:00', '14:45:00', '15:00:00', '15:15:00', '15:30:00', '15:45:00',
       '16:00:00', '16:15:00', '16:30:00', '16:45:00', '17:00:00', '17:15:00',
       '17:30:00', '17:45:00', '18:00:00', '18:15:00', '18:30:00', '18:45:00',
       '19:00:00', '19:15:00', '19:30:00', '19:45:00', '20:00:00', '20:15:00',
       '20:30:00', '20:45:00', '21:00:00', '21:15:00', '21:30:00', '21:45:00',
       '22:00:00', '22:15:00', '22:30:00', '22:45:00', '23:00:00', '23:15:00',
       '23:30:00', '23:45:00']].groupby(['Company',df.Date.dt.year]).mean()

# %%
df1
# Out:
#                    00:00:00    00:15:00    00:30:00    00:45:00    01:00:00  \
# Company    Date
# 50Hertz    2019  143.320611  142.351145  142.366412  142.000000  141.900763
#            2020  141.894737  141.124060  140.936090  140.838346  140.281955
# Amprion    2019  106.992366  106.679389  106.091603  105.549618  108.083969
#            2020   93.751880   94.312030   94.424812   94.033835   93.657895
# TenneTTSO  2019  150.866183  150.450992  150.152901  149.611679  148.946412
#            2020  141.603835  141.457105  141.203120  141.206278  140.931617
# TransnetBW 2019   39.293740   39.462290   39.165191   39.138321   39.369084
#            2020   30.899023   30.604737   30.354023   29.871128   29.731955
#
#                    01:15:00    01:30:00    01:45:00    02:00:00    02:15:00  \
# Company    Date
# 50Hertz    2019  141.381679  140.648855  140.923664  140.732824  140.458015
#            2020  140.037594  139.462406  139.112782  138.646617  138.560150
# ...

# %% [markdown]
# **5.a**
# Write the code to extract a dataframe for each time point (00:00:00 and 12:00:00) and put them in
# their own objects name midnight and noon. When you have done this you will have two Pandas
# Series that look like below.

# %%
midnight=df1['00:00:00']

# %%
midnight
# Out:
# Company     Date
# 50Hertz     2019    143.320611
#             2020    141.894737
# Amprion     2019    106.992366
#             2020     93.751880
# TenneTTSO   2019    150.866183
#             2020    141.603835
# TransnetBW  2019     39.293740
#             2020     30.899023
# Name: 00:00:00, dtype: float64

# %%
noon=df1['12:00:00']

# %%
noon
# Out:
# Company     Date
# 50Hertz     2019    142.473282
#             2020    163.398496
# Amprion     2019    100.572519
#             2020    101.357143
# TenneTTSO   2019    149.229466
#             2020    162.944436
# TransnetBW  2019     37.772366
#             2020     25.731053
# Name: 12:00:00, dtype: float64

# %% [markdown]
# **5.b & 5.c**
# Write the code to create a horizontal bar chart for each dataset that look the those below. Note:
# These are two separate charts, they are not subplots. Save each chart seperately.

# %%
midnight.index=midnight.index.map(str)

# %%
midplt=plt.barh(midnight.index, midnight.values)
plt.title('TW/hours by Company/year @ Midnight')
plt.savefig('midnight.png')

# %%
noon.index=noon.index.map(str)

# %%
noonplt=plt.barh(noon.index, noon.values,color='red')
plt.title('TW/hours by Company/year @ Noon')
plt.savefig('noon.png')

# %% [markdown]
# **6**
# You have been asked to combine the two bar graphs into a single graph that shares the x-axis. And, it will
# be published in newspaper in grayscale, so the top graph should be silver and the bottom should be gray.
# Save the file as ‘combined_bar_chart.png’. The chart should appear as below:

# %%
fig = plt.figure(figsize=(18,6))
ax1 = fig.add_subplot(221)
ax1.barh(midnight.index, midnight.values,color='silver')
ax2 = fig.add_subplot(223)
ax2.barh(noon.index, noon.values,color='gray')
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# **7**
# You have been asked to write a function that accepts the ungrouped dataframe, the company name, date,
# and a plotting color that generates an area graph for that particular company/day. Use this function
# signature: daily_view(dataframe, company, date, color). Your function should produce
# the following graph:

# %%
hert=df.query("Company=='50Hertz' and Date=='2019-8-24'",inplace=False)

# %%
hert
# Out:
#      Company       Date  00:00:00  00:15:00  00:30:00  00:45:00  01:00:00  \
# 398  50Hertz 2019-08-24      37.0      38.0      35.0      35.0      31.0
#
#      01:15:00  01:30:00  01:45:00  ...  21:30:00  21:45:00  22:00:00  \
# 398      32.0      30.0      29.0  ...     118.0     118.0     112.0
#
#      22:15:00  22:30:00  22:45:00  23:00:00  23:15:00  23:30:00  23:45:00
# 398     107.0     104.0     104.0      99.0      95.0      95.0      96.0
#
# [1 rows x 98 columns]

# %%
hert1=hert.iloc[:,2:]

# %%
hert1.T.plot(kind='area', color='purple')
plt.title('Power Production: 50Hertz:2019-8-24')
plt.xlabel('Time of Day')
plt.ylabel('TW/h Generated')
# Out:
# Text(0, 0.5, 'TW/h Generated')

# %% [markdown]
# BONUS (10 points): Generate a unified graph that contains four area charts, one for each company for the
# same day. See example below. Note: I won’t help with this since it is a bonus.

# %%
hert=df.query("Company=='50Hertz' and Date=='2019-8-24'",inplace=False)
hert1=hert.iloc[:,2:]
hert1.T.plot(kind='area', color='purple')
plt.title('Power Production: 50Hertz:2019-8-24')
plt.xlabel('Time of Day')
plt.ylabel('TW/h Generated')

amp=df.query("Company=='Amprion' and Date=='2019-8-24'",inplace=False)
amp1=amp.iloc[:,2:]
amp1.T.plot(kind='area', color='red')
plt.title('Power Production: Amprion:2019-8-24')
plt.xlabel('Time of Day')
plt.ylabel('TW/h Generated')

ten=df.query("Company=='TenneTTSO' and Date=='2019-8-24'",inplace=False)
ten1=ten.iloc[:,2:]
ten1.T.plot(kind='area', color='blue')
plt.title('Power Production: TenneTTSO:2019-8-24')
plt.xlabel('Time of Day')
plt.ylabel('TW/h Generated')

tra=df.query("Company=='TransnetBW' and Date=='2019-8-24'",inplace=False)
tra1=tra.iloc[:,2:]
tra1.T.plot(kind='area', color='green')
plt.title('Power Production: TransnetBW:2019-8-24')
plt.xlabel('Time of Day')
plt.ylabel('TW/h Generated')
# Out:
# Text(0, 0.5, 'TW/h Generated')

# %% [markdown]
# ## Part 2

# %%
di=pd.read_csv('Diamonds.csv')

# %%
di.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.histplot(x=di['price'])

# %%
sns.kdeplot(di['carat'])

# %%
sns.boxplot(x=di['cut'], y=di['price'])

# %%
sns.pairplot(di[['price', 'carat', 'table', 'depth']])

# %%
sns.heatmap(di.corr())

# %%
sns.lineplot(x=di['cut'], y=di['price'])
